# %%
import yaml

with open("/Users/gaganjain/Downloads/ipl/1082625.yaml", 'r') as stream:
    try:
        print(yaml.load(stream))
        doc = yaml.load(f)
    except yaml.YAMLError as exc:
        print(exc)
# Out:
# {'info': {'city': 'Rajkot', 'dates': [datetime.date(2017, 4, 29)], 'match_type': 'T20', 'gender': 'male', 'venue': 'Saurashtra Cricket Association Stadium', 'competition': 'IPL', 'teams': ['Gujarat Lions', 'Mumbai Indians'], 'umpires': ['AK Chaudhary', 'CB Gaffaney'], 'toss': {'decision': 'bat', 'winner': 'Gujarat Lions'}, 'player_of_match': ['KH Pandya'], 'outcome': {'eliminator': 'Mumbai Indians', 'result': 'tie'}, 'overs': 20}, 'innings': [{'1st innings': {'deliveries': [{0.1: {'batsman': 'Ishan Kishan', 'bowler': 'MJ McClenaghan', 'runs': {'batsman': 0, 'total': 1, 'extras': 1}, 'extras': {'wides': 1}, 'non_striker': 'BB McCullum'}}, {0.2: {'batsman': 'Ishan Kishan', 'bowler': 'MJ McClenaghan', 'runs': {'batsman': 0, 'total': 0, 'extras': 0}, 'non_striker': 'BB McCullum'}}, {0.3: {'batsman': 'Ishan Kishan', 'bowler': 'MJ McClenaghan', 'runs': {'batsman': 0, 'total': 0, 'extras': 0}, 'non_striker': 'BB McCullum'}}, {0.4: {'batsman': 'Ishan Kishan', 'bowler': 'MJ McClenaghan', 'run
# ...

# %%
import yaml
with open('/Users/gaganjain/Downloads/ipl/1082625.yaml', 'r') as f:
    doc = yaml.load(f)
    
#print(doc)
for innings in doc["innings"]:
    for key, value in innings.iteritems():
        print key
#for key, value in doc.iteritems():
#    print key, value
txt = doc["innings"][0]["1st innings"]["deliveries"]
#print(txt)
# Out:
# 1st innings
# 2nd innings
# Mumbai Indians Super Over
# Gujarat Lions Super Over

# %%
import pandas as pd

#extract city
city = doc["info"]["city"]
print(city)

#extract date
dates = doc["info"]["dates"]
date = datetime.datetime.strptime(str(dates[0]),'%Y-%m-%d').strftime('%m/%d/%Y')
print(date)

#extract team 1
team1 = doc["info"]["teams"][0]
print(team1)

#extract team 2
team2 = doc["info"]["teams"][1]
print(team2)

#extract toss_winner
toss_winner = doc["info"]["toss"]["winner"]
print(toss_winner)

#extract toss_decision
toss_decision = doc["info"]["toss"]["decision"]
print(toss_decision)

#extract result and dl_dismissed
#result = 

#extract winner
winner = doc["info"]["outcome"]["winner"]
print(winner)

win_by_runs = doc["info"]["outcome"]["by"]["runs"]
print(win_by_runs)

#win_by_wickets = doc["info"]["outcome"]["by"]["wickets"]
# Out:
# Hyderabad
# 04/05/2017
# Sunrisers Hyderabad
# Royal Challengers Bangalore
# Royal Challengers Bangalore
# field
# Sunrisers Hyderabad
# 35
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-ffdc1f06c88a> in <module>()
#      35 win_by_runs = doc["info"]["outcome"]["by"]["runs"]
#      36 print(win_by_runs)
# ---> 37 win_by_wickets = doc["info"]["outcome"]["by"]["wickets"]
#
# KeyError: 'wickets'
